# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#read in the dataset
data = pd.read_csv('owid-covid-data.csv')
data.head()
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      ABW  North America    Aruba  2020-03-13          2.0        2.0
# 1      ABW  North America    Aruba  2020-03-19          NaN        NaN
# 2      ABW  North America    Aruba  2020-03-20          4.0        2.0
# 3      ABW  North America    Aruba  2020-03-21          NaN        NaN
# 4      ABW  North America    Aruba  2020-03-22          NaN        NaN
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         0.0                  NaN
# 1               0.286           NaN         NaN                  0.0
# 2               0.286           NaN         0.0                  0.0
# 3               0.286           NaN         NaN                  0.0
# 4               0.286           NaN         NaN                  0.0
#
#             ...             gdp_per_capita  extreme_poverty  \
# ...

# %%
data.set_index("iso_code", inplace = True)
data.head()
# Out:
#               continent location        date  total_cases  new_cases  \
# iso_code
# ABW       North America    Aruba  2020-03-13          2.0        2.0
# ABW       North America    Aruba  2020-03-19          NaN        NaN
# ABW       North America    Aruba  2020-03-20          4.0        2.0
# ABW       North America    Aruba  2020-03-21          NaN        NaN
# ABW       North America    Aruba  2020-03-22          NaN        NaN
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# ABW                      NaN           NaN         0.0                  NaN
# ABW                    0.286           NaN         NaN                  0.0
# ABW                    0.286           NaN         0.0                  0.0
# ABW                    0.286           NaN         NaN                  0.0
# ABW                    0.286           NaN         NaN                  0.0
#
# ...

# %%
data.shape
# Out:
# (51166, 40)

# %%
data["date"]= pd.to_datetime(data["date"])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51166 entries, ABW to nan
# Data columns (total 40 columns):
# continent                          50578 non-null object
# location                           51166 non-null object
# date                               51166 non-null datetime64[ns]
# total_cases                        47553 non-null float64
# new_cases                          50281 non-null float64
# new_cases_smoothed                 49495 non-null float64
# total_deaths                       38789 non-null float64
# new_deaths                         50281 non-null float64
# new_deaths_smoothed                49495 non-null float64
# total_cases_per_million            47295 non-null float64
# new_cases_per_million              50217 non-null float64
# new_cases_smoothed_per_million     49430 non-null float64
# total_deaths_per_million           38546 non-null float64
# new_deaths_per_million             50217 non-null float64
# ...

# %%
data_usa = data.loc[["USA"]]

# %%
data_usa.head()
# Out:
#               continent       location       date  total_cases  new_cases  \
# iso_code
# USA       North America  United States 2019-12-31          NaN        0.0
# USA       North America  United States 2020-01-01          NaN        0.0
# USA       North America  United States 2020-01-02          NaN        0.0
# USA       North America  United States 2020-01-03          NaN        0.0
# USA       North America  United States 2020-01-04          NaN        0.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# USA                      NaN           NaN         0.0                  NaN
# USA                      NaN           NaN         0.0                  NaN
# USA                      NaN           NaN         0.0                  NaN
# USA                      NaN           NaN         0.0                  NaN
# USA                      NaN           NaN         0.0                  NaN
#
# ...

# %%
data_usa.shape
# Out:
# (294, 40)

# %%
data_usa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 294 entries, USA to USA
# Data columns (total 40 columns):
# continent                          294 non-null object
# location                           294 non-null object
# date                               294 non-null datetime64[ns]
# total_cases                        273 non-null float64
# new_cases                          294 non-null float64
# new_cases_smoothed                 288 non-null float64
# total_deaths                       233 non-null float64
# new_deaths                         294 non-null float64
# new_deaths_smoothed                288 non-null float64
# total_cases_per_million            273 non-null float64
# new_cases_per_million              294 non-null float64
# new_cases_smoothed_per_million     288 non-null float64
# total_deaths_per_million           233 non-null float64
# new_deaths_per_million             294 non-null float64
# new_deaths_smoothed_per_million    288 non-null float64
# ...

# %%
data.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  4.755300e+04   50281.000000        49495.000000  3.878900e+04
# mean   1.318472e+05    1595.312265         1576.630315  6.026920e+03
# std    1.320386e+06   14369.302512        14107.081477  4.877375e+04
# min    1.000000e+00   -8261.000000         -552.000000  1.000000e+00
# 25%    1.410000e+02       0.000000            0.714000  1.100000e+01
# 50%    1.651000e+03      12.000000           17.000000  6.900000e+01
# 75%    1.654800e+04     189.000000          196.429000  6.030000e+02
# max    4.010696e+07  396737.000000       352319.857000  1.114636e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  50281.000000         49495.000000             47295.000000
# mean      44.336191            44.404981              2427.244083
# std      370.634763           360.386558              4814.319832
# min    -1918.000000          -232.143000                 0.001000
# ...

# %%
data_usa.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed   total_deaths  \
# count  2.730000e+02    294.000000          288.000000     233.000000
# mean   2.732652e+06  27736.717687        27712.492083  113637.656652
# std    2.632990e+06  21754.117009        21021.172267   70521.666844
# min    1.000000e+00      0.000000            0.000000       1.000000
# 25%    1.246650e+05    391.000000          718.321250   56245.000000
# 50%    1.872660e+06  26700.000000        27759.000000  121979.000000
# 75%    5.141207e+06  44336.750000        43353.500250  175406.000000
# max    8.154595e+06  78427.000000        67373.571000  219674.000000
#
#         new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count   294.000000           288.000000               273.000000
# mean    747.190476           755.516361              8255.681304
# std     714.949898           629.205206              7954.588618
# min       0.000000             0.000000                 0.003000
# ...

# %%
data_usa.isnull().sum()
# Out:
# continent                            0
# location                             0
# date                                 0
# total_cases                         21
# new_cases                            0
# new_cases_smoothed                   6
# total_deaths                        61
# new_deaths                           0
# new_deaths_smoothed                  6
# total_cases_per_million             21
# new_cases_per_million                0
# new_cases_smoothed_per_million       6
# total_deaths_per_million            61
# new_deaths_per_million               0
# new_deaths_smoothed_per_million      6
# new_tests                           64
# total_tests                         64
# total_tests_per_thousand            64
# new_tests_per_thousand              64
# new_tests_smoothed                  71
# new_tests_smoothed_per_thousand     71
# tests_per_case                      71
# positive_rate                       71
# tests_units                         64
# ...

# %%
df = data_usa.drop("handwashing_facilities", axis=1, inplace=True)
# Out:
# C:\Users\Sumayyah Musa\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
df = data_usa.dropna()

# %%
df.isnull().sum()
# Out:
# continent                          0
# location                           0
# date                               0
# total_cases                        0
# new_cases                          0
# new_cases_smoothed                 0
# total_deaths                       0
# new_deaths                         0
# new_deaths_smoothed                0
# total_cases_per_million            0
# new_cases_per_million              0
# new_cases_smoothed_per_million     0
# total_deaths_per_million           0
# new_deaths_per_million             0
# new_deaths_smoothed_per_million    0
# new_tests                          0
# total_tests                        0
# total_tests_per_thousand           0
# new_tests_per_thousand             0
# new_tests_smoothed                 0
# new_tests_smoothed_per_thousand    0
# tests_per_case                     0
# positive_rate                      0
# tests_units                        0
# stringency_index                   0
# ...

# %%
df.shape
# Out:
# (219, 39)

# %%
df.head()
# Out:
#               continent       location       date  total_cases  new_cases  \
# iso_code
# USA       North America  United States 2020-03-08        433.0       95.0
# USA       North America  United States 2020-03-09        554.0      121.0
# USA       North America  United States 2020-03-10        754.0      200.0
# USA       North America  United States 2020-03-11       1025.0      271.0
# USA       North America  United States 2020-03-12       1312.0      287.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# USA                   52.000          17.0         3.0                2.286
# USA                   66.429          21.0         4.0                2.714
# USA                   93.000          26.0         5.0                2.857
# USA                  128.571          28.0         2.0                2.714
# USA                  164.714          30.0         2.0                2.714
#
# ...

# %%
df_by_month = df.groupby(df['date'].dt.month)["total_cases_per_million"].sum()
df_by_month
# Out:
# date
# 3       2794.008
# 4      56480.013
# 5     134438.618
# 6     193484.715
# 7     330078.245
# 8     498154.502
# 9     597960.989
# 10    271619.121
# Name: total_cases_per_million, dtype: float64

# %%
df_by_month.plot(kind='bar')

# %%
data.drop('handwashing_facilities', axis=1, inplace=True)

# %%
df_uk = data.loc[['GBR']]
df_uk.head()
# Out:
#          continent        location       date  total_cases  new_cases  \
# iso_code
# GBR         Europe  United Kingdom 2019-12-31          NaN        0.0
# GBR         Europe  United Kingdom 2020-01-01          NaN        0.0
# GBR         Europe  United Kingdom 2020-01-02          NaN        0.0
# GBR         Europe  United Kingdom 2020-01-03          NaN        0.0
# GBR         Europe  United Kingdom 2020-01-04          NaN        0.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# GBR                      NaN           NaN         0.0                  NaN
# GBR                      NaN           NaN         0.0                  NaN
# GBR                      NaN           NaN         0.0                  NaN
# GBR                      NaN           NaN         0.0                  NaN
# GBR                      NaN           NaN         0.0                  NaN
#
# ...

# %%
df_uk.shape
# Out:
# (294, 39)

# %%
df_uk.isnull().sum()
# Out:
# continent                            0
# location                             0
# date                                 0
# total_cases                         32
# new_cases                            0
# new_cases_smoothed                   6
# total_deaths                        67
# new_deaths                           0
# new_deaths_smoothed                  6
# total_cases_per_million             32
# new_cases_per_million                0
# new_cases_smoothed_per_million       6
# total_deaths_per_million            67
# new_deaths_per_million               0
# new_deaths_smoothed_per_million      6
# new_tests                           95
# total_tests                         95
# total_tests_per_thousand            95
# new_tests_per_thousand              95
# new_tests_smoothed                 102
# new_tests_smoothed_per_thousand    102
# tests_per_case                     102
# positive_rate                      102
# tests_units                         95
# ...

# %%
df_UK = df_uk.dropna()

# %%
df_UK.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 180 entries, GBR to GBR
# Data columns (total 39 columns):
# continent                          180 non-null object
# location                           180 non-null object
# date                               180 non-null datetime64[ns]
# total_cases                        180 non-null float64
# new_cases                          180 non-null float64
# new_cases_smoothed                 180 non-null float64
# total_deaths                       180 non-null float64
# new_deaths                         180 non-null float64
# new_deaths_smoothed                180 non-null float64
# total_cases_per_million            180 non-null float64
# new_cases_per_million              180 non-null float64
# new_cases_smoothed_per_million     180 non-null float64
# total_deaths_per_million           180 non-null float64
# new_deaths_per_million             180 non-null float64
# new_deaths_smoothed_per_million    180 non-null float64
# ...

# %%
df_nz = data.loc[["NZL"]]
df_nz.head()
# Out:
#          continent     location       date  total_cases  new_cases  \
# iso_code
# NZL        Oceania  New Zealand 2019-12-31          NaN        0.0
# NZL        Oceania  New Zealand 2020-01-01          NaN        0.0
# NZL        Oceania  New Zealand 2020-01-02          NaN        0.0
# NZL        Oceania  New Zealand 2020-01-03          NaN        0.0
# NZL        Oceania  New Zealand 2020-01-04          NaN        0.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# NZL                      NaN           NaN         0.0                  NaN
# NZL                      NaN           NaN         0.0                  NaN
# NZL                      NaN           NaN         0.0                  NaN
# NZL                      NaN           NaN         0.0                  NaN
# NZL                      NaN           NaN         0.0                  NaN
#
#           total_cases_per_million           ...             aged_70_older  \
# ...

# %%
df_nz.isnull().sum()
# Out:
# continent                            0
# location                             0
# date                                 0
# total_cases                         68
# new_cases                            9
# new_cases_smoothed                   6
# total_deaths                        89
# new_deaths                           9
# new_deaths_smoothed                  6
# total_cases_per_million             68
# new_cases_per_million                9
# new_cases_smoothed_per_million       6
# total_deaths_per_million            89
# new_deaths_per_million               9
# new_deaths_smoothed_per_million      6
# new_tests                           63
# total_tests                         63
# total_tests_per_thousand            63
# new_tests_per_thousand              63
# new_tests_smoothed                  69
# new_tests_smoothed_per_thousand     69
# tests_per_case                      87
# positive_rate                       69
# tests_units                         62
# ...

# %%
df_nz.drop('extreme_poverty', axis=1, inplace=True)
# Out:
# C:\Users\Sumayyah Musa\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
df_NZ = df_nz.dropna()
df_NZ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 184 entries, NZL to NZL
# Data columns (total 38 columns):
# continent                          184 non-null object
# location                           184 non-null object
# date                               184 non-null datetime64[ns]
# total_cases                        184 non-null float64
# new_cases                          184 non-null float64
# new_cases_smoothed                 184 non-null float64
# total_deaths                       184 non-null float64
# new_deaths                         184 non-null float64
# new_deaths_smoothed                184 non-null float64
# total_cases_per_million            184 non-null float64
# new_cases_per_million              184 non-null float64
# new_cases_smoothed_per_million     184 non-null float64
# total_deaths_per_million           184 non-null float64
# new_deaths_per_million             184 non-null float64
# new_deaths_smoothed_per_million    184 non-null float64
# ...

# %%
df_ca = data.loc['CAN']
df_ca.head()
# Out:
#               continent location       date  total_cases  new_cases  \
# iso_code
# CAN       North America   Canada 2019-12-31          NaN        0.0
# CAN       North America   Canada 2020-01-01          NaN        0.0
# CAN       North America   Canada 2020-01-02          NaN        0.0
# CAN       North America   Canada 2020-01-03          NaN        0.0
# CAN       North America   Canada 2020-01-04          NaN        0.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# CAN                      NaN           NaN         0.0                  NaN
# CAN                      NaN           NaN         0.0                  NaN
# CAN                      NaN           NaN         0.0                  NaN
# CAN                      NaN           NaN         0.0                  NaN
# CAN                      NaN           NaN         0.0                  NaN
#
#           total_cases_per_million           ...             aged_70_older  \
# ...

# %%
df_ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 294 entries, CAN to CAN
# Data columns (total 39 columns):
# continent                          294 non-null object
# location                           294 non-null object
# date                               294 non-null datetime64[ns]
# total_cases                        268 non-null float64
# new_cases                          294 non-null float64
# new_cases_smoothed                 288 non-null float64
# total_deaths                       224 non-null float64
# new_deaths                         294 non-null float64
# new_deaths_smoothed                288 non-null float64
# total_cases_per_million            268 non-null float64
# new_cases_per_million              294 non-null float64
# new_cases_smoothed_per_million     288 non-null float64
# total_deaths_per_million           224 non-null float64
# new_deaths_per_million             294 non-null float64
# new_deaths_smoothed_per_million    288 non-null float64
# ...

# %%
df_ca.isnull().sum()
# Out:
# continent                           0
# location                            0
# date                                0
# total_cases                        26
# new_cases                           0
# new_cases_smoothed                  6
# total_deaths                       70
# new_deaths                          0
# new_deaths_smoothed                 6
# total_cases_per_million            26
# new_cases_per_million               0
# new_cases_smoothed_per_million      6
# total_deaths_per_million           70
# new_deaths_per_million              0
# new_deaths_smoothed_per_million     6
# new_tests                          98
# total_tests                        88
# total_tests_per_thousand           88
# new_tests_per_thousand             98
# new_tests_smoothed                 85
# new_tests_smoothed_per_thousand    85
# tests_per_case                     85
# positive_rate                      85
# tests_units                        78
# stringency_index                    5
# ...

# %%
df_CA = df_ca.dropna()
df_CA.head()
# Out:
#               continent location       date  total_cases  new_cases  \
# iso_code
# CAN       North America   Canada 2020-03-25       1959.0      313.0
# CAN       North America   Canada 2020-03-26       3385.0     1426.0
# CAN       North America   Canada 2020-03-27       4018.0      633.0
# CAN       North America   Canada 2020-03-28       4675.0      657.0
# CAN       North America   Canada 2020-03-29       5386.0      711.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# CAN                  198.571          27.0         3.0                2.714
# CAN                  385.000          35.0         8.0                3.714
# CAN                  453.143          39.0         4.0                4.143
# CAN                  529.143          53.0        14.0                5.857
# CAN                  583.429          60.0         7.0                6.000
#
#           total_cases_per_million           ...             aged_70_older  \
# ...

# %%
x = df['date'].values
y = df['total_cases_per_million'].values

x1 = df_UK['date'].values
y1 = df_UK['total_cases_per_million'].values

x2 = df_NZ['date'].values
y2 = df_NZ['total_cases_per_million'].values

x3 = df_CA['date'].values
y3 = df_CA['total_cases_per_million'].values

plt.figure(figsize=(10,6))
plt.plot(x,y, color='skyblue')
plt.plot(x1,y1, color='r')
plt.plot(x2,y2, color = 'g')
plt.plot(x3,y3, color = 'olive')

plt.show()

# %%
df_NZ_by_month = df_NZ.groupby(df_NZ['date'].dt.month)["total_cases_per_million"].sum()
df_NZ_by_month
# Out:
# date
# 3      347.349
# 4     6349.135
# 5     6656.460
# 6     3625.498
# 7     7691.666
# 8     8220.049
# 9     8706.755
# 10    5316.209
# Name: total_cases_per_million, dtype: float64

# %%
pd.DataFrame(df_by_month)
# Out:
#       total_cases_per_million
# date
# 3                    2794.008
# 4                   56480.013
# 5                  134438.618
# 6                  193484.715
# 7                  330078.245
# 8                  498154.502
# 9                  597960.989
# 10                 271619.121

# %%
pd.DataFrame(df_NZ_by_month)
# Out:
#       total_cases_per_million
# date
# 3                     347.349
# 4                    6349.135
# 5                    6656.460
# 6                    3625.498
# 7                    7691.666
# 8                    8220.049
# 9                    8706.755
# 10                   5316.209

# %%
df_NZ_by_month.plot(kind = 'bar')
df_by_month.plot(kind='bar')

# %%
df.describe()
print(df[['stringency_index']].min())
print(df[['stringency_index']].max())
# Out:
# stringency_index    20.37
# dtype: float64
# stringency_index    72.69
# dtype: float64

# %%
df.head()
# Out:
#               continent       location       date  total_cases  new_cases  \
# iso_code
# USA       North America  United States 2020-03-08        433.0       95.0
# USA       North America  United States 2020-03-09        554.0      121.0
# USA       North America  United States 2020-03-10        754.0      200.0
# USA       North America  United States 2020-03-11       1025.0      271.0
# USA       North America  United States 2020-03-12       1312.0      287.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# USA                   52.000          17.0         3.0                2.286
# USA                   66.429          21.0         4.0                2.714
# USA                   93.000          26.0         5.0                2.857
# USA                  128.571          28.0         2.0                2.714
# USA                  164.714          30.0         2.0                2.714
#
# ...

# %%
df_NZ.head()
# Out:
#          continent     location       date  total_cases  new_cases  \
# iso_code
# NZL        Oceania  New Zealand 2020-03-29        476.0       60.0
# NZL        Oceania  New Zealand 2020-03-30        552.0       76.0
# NZL        Oceania  New Zealand 2020-03-31        647.0       95.0
# NZL        Oceania  New Zealand 2020-04-01        647.0        0.0
# NZL        Oceania  New Zealand 2020-04-02        723.0       76.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# NZL                   58.571           1.0         1.0                0.143
# NZL                   64.286           1.0         0.0                0.143
# NZL                   72.143           1.0         0.0                0.143
# NZL                   65.429           1.0         0.0                0.143
# NZL                   65.857           1.0         0.0                0.143
#
#           total_cases_per_million           ...             aged_65_older  \
# ...

# %%
df_CA.head()
# Out:
#               continent location       date  total_cases  new_cases  \
# iso_code
# CAN       North America   Canada 2020-03-25       1959.0      313.0
# CAN       North America   Canada 2020-03-26       3385.0     1426.0
# CAN       North America   Canada 2020-03-27       4018.0      633.0
# CAN       North America   Canada 2020-03-28       4675.0      657.0
# CAN       North America   Canada 2020-03-29       5386.0      711.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# CAN                  198.571          27.0         3.0                2.714
# CAN                  385.000          35.0         8.0                3.714
# CAN                  453.143          39.0         4.0                4.143
# CAN                  529.143          53.0        14.0                5.857
# CAN                  583.429          60.0         7.0                6.000
#
#           total_cases_per_million           ...             aged_70_older  \
# ...

# %%
df_UK.head()
# Out:
#          continent        location       date  total_cases  new_cases  \
# iso_code
# GBR         Europe  United Kingdom 2020-04-08      66054.0     5282.0
# GBR         Europe  United Kingdom 2020-04-09      71504.0     5450.0
# GBR         Europe  United Kingdom 2020-04-10      76635.0     5131.0
# GBR         Europe  United Kingdom 2020-04-11      81493.0     4858.0
# GBR         Europe  United Kingdom 2020-04-12      85806.0     4313.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# GBR                 4585.714        7545.0      1105.0              727.429
# GBR                 4719.429        8575.0      1030.0              778.571
# GBR                 4750.571        9691.0      1116.0              844.143
# GBR                 4749.143       10813.0      1122.0              899.286
# GBR                 4663.714       11656.0       843.0              911.714
#
# ...

# %%
df_au = data.loc[['AUS']]
df_au.head()
# Out:
#          continent   location       date  total_cases  new_cases  \
# iso_code
# AUS        Oceania  Australia 2019-12-31          NaN        0.0
# AUS        Oceania  Australia 2020-01-01          NaN        0.0
# AUS        Oceania  Australia 2020-01-02          NaN        0.0
# AUS        Oceania  Australia 2020-01-03          NaN        0.0
# AUS        Oceania  Australia 2020-01-04          NaN        0.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# AUS                      NaN           NaN         0.0                  NaN
# AUS                      NaN           NaN         0.0                  NaN
# AUS                      NaN           NaN         0.0                  NaN
# AUS                      NaN           NaN         0.0                  NaN
# AUS                      NaN           NaN         0.0                  NaN
#
#           total_cases_per_million           ...             aged_70_older  \
# ...

# %%
df_au.isnull().sum()
# Out:
# continent                            0
# location                             0
# date                                 0
# total_cases                         25
# new_cases                            0
# new_cases_smoothed                   6
# total_deaths                        61
# new_deaths                           0
# new_deaths_smoothed                  6
# total_cases_per_million             25
# new_cases_per_million                0
# new_cases_smoothed_per_million       6
# total_deaths_per_million            61
# new_deaths_per_million               0
# new_deaths_smoothed_per_million      6
# new_tests                          131
# total_tests                        117
# total_tests_per_thousand           117
# new_tests_per_thousand             131
# new_tests_smoothed                  90
# new_tests_smoothed_per_thousand     90
# tests_per_case                      90
# positive_rate                       90
# tests_units                         83
# ...

# %%
df_AU = df_au.dropna()
df_AU.head()
# Out:
#          continent   location       date  total_cases  new_cases  \
# iso_code
# AUS        Oceania  Australia 2020-04-06       5744.0       57.0
# AUS        Oceania  Australia 2020-04-07       5844.0      100.0
# AUS        Oceania  Australia 2020-04-08       5956.0      112.0
# AUS        Oceania  Australia 2020-04-09       6052.0       96.0
# AUS        Oceania  Australia 2020-04-10       6152.0      100.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# AUS                  235.857          36.0         2.0                2.857
# AUS                  183.857          42.0         6.0                3.286
# AUS                  178.429          45.0         3.0                3.571
# AUS                  153.714          50.0         5.0                4.143
# AUS                  132.571          52.0         2.0                4.143
#
#           total_cases_per_million           ...             aged_70_older  \
# ...

# %%
df_AU.shape
# Out:
# (159, 39)

# %%
iso_joined = pd.concat([df,df_CA,df_UK,df_NZ,df_AU], join = "inner")
iso_joined.tail()
# Out:
#          continent   location       date  total_cases  new_cases  \
# iso_code
# AUS        Oceania  Australia 2020-09-29      27044.0        4.0
# AUS        Oceania  Australia 2020-09-30      27063.0       19.0
# AUS        Oceania  Australia 2020-10-01      27063.0        0.0
# AUS        Oceania  Australia 2020-10-07      27174.0       25.0
# AUS        Oceania  Australia 2020-10-08      27182.0        8.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# AUS                   18.857         875.0         3.0                3.429
# AUS                   17.286         882.0         7.0                4.000
# AUS                   12.857         882.0         0.0                3.286
# AUS                   15.857         895.0         1.0                1.857
# AUS                   17.000         897.0         2.0                2.143
#
#           total_cases_per_million           ...             aged_65_older  \
# ...

# %%
iso_joined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 928 entries, USA to AUS
# Data columns (total 38 columns):
# continent                          928 non-null object
# location                           928 non-null object
# date                               928 non-null datetime64[ns]
# total_cases                        928 non-null float64
# new_cases                          928 non-null float64
# new_cases_smoothed                 928 non-null float64
# total_deaths                       928 non-null float64
# new_deaths                         928 non-null float64
# new_deaths_smoothed                928 non-null float64
# total_cases_per_million            928 non-null float64
# new_cases_per_million              928 non-null float64
# new_cases_smoothed_per_million     928 non-null float64
# total_deaths_per_million           928 non-null float64
# new_deaths_per_million             928 non-null float64
# new_deaths_smoothed_per_million    928 non-null float64
# ...

# %%
iso_joined.to_csv('covid-data.csv')

# %%
print(iso_joined[['stringency_index']].min())
print(iso_joined[['stringency_index']].max())
# Out:
# stringency_index    20.37
# dtype: float64
# stringency_index    96.3
# dtype: float64

# %%
iso_joined['date'] = pd.to_datetime(iso_joined['date'])

# %%
iso_m = iso_joined.groupby(iso_joined['date'].dt.strftime('%B'))['stringency_index'].sum().sort_values()
print(iso_m)
# Out:
# date
# March         2041.28
# October       2388.40
# September     7627.18
# June          8287.47
# July          8749.91
# August        9513.89
# May          10336.18
# April        10758.22
# Name: stringency_index, dtype: float64

# %%
grouped_single = iso_joined.groupby('iso_code').agg({'stringency_index': ['mean', 'min', 'max']})

print(grouped_single)
# Out:
#          stringency_index
#                      mean    min    max
# iso_code
# AUS             68.303019  46.76  79.17
# CAN             67.971237  60.65  74.54
# GBR             70.107944  64.35  79.63
# NZL             48.018804  22.22  96.30
# USA             67.327900  20.37  72.69

# %%
from sorted_months_weekdays import Month_Sorted_Month, Weekday_Sorted_Week

# %%
grouped_iso = iso_joined.groupby(['location', (iso_joined['date'].dt.strftime('%B'))]).agg({'stringency_index': ['mean'], 'total_cases_per_million':['mean'], 
                                                                                               'total_deaths_per_million': ['mean'],'total_tests_per_thousand':'mean'})
grouped_iso.reset_index(inplace=True)

grouped_iso.columns = ['location','month','mean_stringency_index', 'mean_total_cases_per_million', 'mean_total_deaths_per_million','mean_total_tests_per_thousand']

# %%
grouped_iso.to_csv("grouped-covid-data.csv")

# %%
grouped_iso.columns
# Out:
# Index(['location', 'month', 'mean_stringency_index',
#        'mean_total_cases_per_million', 'mean_total_deaths_per_million',
#        'mean_total_tests_per_thousand'],
#       dtype='object')

# %%
sub_data = pd.read_csv('grouped-covid-data.csv',index_col=0)
sub_data.head()
# Out:
#     location   month  mean_stringency_index  mean_total_cases_per_million  \
# 0  Australia   April              71.220800                    252.503200
# 1  Australia  August              78.860833                    861.595500
# 2  Australia    July              70.007857                    416.050964
# 3  Australia    June              53.286667                    289.338600
# 4  Australia     May              67.352258                    274.275839
#
#    mean_total_deaths_per_million  mean_total_tests_per_thousand
# 0                       2.588200                      16.363360
# 1                      14.251708                     202.335458
# 2                       4.607714                     127.075679
# 3                       4.014300                      74.306167
# 4                       3.855839                      39.305968

# %%
type(sub_data)
# Out:
# pandas.core.frame.DataFrame

# %%
sub_data.describe()
# Out:
#        mean_stringency_index  mean_total_cases_per_million  \
# count              38.000000                     38.000000
# mean               64.593447                   3645.043248
# std                16.110626                   5345.235972
# min                22.220000                    113.392333
# 25%                61.715761                    278.041529
# 50%                67.613065                   1801.675159
# 75%                72.353276                   4332.681137
# max                96.300000                  22634.926750
#
#        mean_total_deaths_per_million  mean_total_tests_per_thousand
# count                      38.000000                      38.000000
# mean                      213.418443                     122.614080
# std                       237.793610                     105.269210
# min                         0.207000                       1.268292
# 25%                         4.562000                      34.775887
# ...

# %%
sub_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38 entries, 0 to 37
# Data columns (total 6 columns):
# location                         38 non-null object
# month                            38 non-null object
# mean_stringency_index            38 non-null float64
# mean_total_cases_per_million     38 non-null float64
# mean_total_deaths_per_million    38 non-null float64
# mean_total_tests_per_thousand    38 non-null float64
# dtypes: float64(4), object(2)
# memory usage: 2.1+ KB

# %%
sub_data.columns = ['location','month', 'mean_stringency_index', 'mean_total_cases_per_million', 
                    'mean_total_deaths_per_million','mean_total_tests_per_thousand']
sub_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38 entries, 0 to 37
# Data columns (total 6 columns):
# location                         38 non-null object
# month                            38 non-null object
# mean_stringency_index            38 non-null float64
# mean_total_cases_per_million     38 non-null float64
# mean_total_deaths_per_million    38 non-null float64
# mean_total_tests_per_thousand    38 non-null float64
# dtypes: float64(4), object(2)
# memory usage: 2.1+ KB

# %%
fig, ax = plt.subplots()

x = sub_data['location']
y = sub_data['mean_total_cases_per_million']

plt.figure(figsize=(10,6))
ax.bar(x,y, color='red')

plt.show()

# %%
import mpld3
mpld3.display(fig)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el1540028771246371361041455785"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
# ...

# %%
mpld3.enable_notebook()

# %%
import mpld3
from mpld3 import plugins
from mpld3.utils import get_id
import numpy as np
import collections
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(12, 8))
x = np.arange(len(sub_data.location.unique()))

# Define bar width. We'll use this to offset the second bar.
bar_width = 0.4

# Note we add the `width` parameter now which sets the width of each bar.
b1 = ax.bar(x, sub_data.loc[sub_data['month'] == 'April', 'mean_total_cases_per_million'],
            width=bar_width, label = 'April')

b2 = ax.bar(x + bar_width, sub_data.loc[sub_data['month'] == 'September', 'mean_total_cases_per_million'],
            width=bar_width, label = 'September')

ax.set_xticks(x + bar_width / 2)
ax.set_xticklabels(sub_data.location.unique())

# Use Seaborn's context settings to make fonts larger.
import seaborn as sns
sns.set_context('talk')

# Add legend.
ax.legend()

# Axis styling.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')
ax.tick_params(bottom=False, left=False)
ax.set_axisbelow(True)
ax.yaxis.grid(False)
ax.xaxis.grid(False)

# Add axis and chart labels.
ax.set_xlabel('Country', labelpad=15)
ax.set_ylabel('Total Cases per Million', labelpad=15)
ax.set_title('Total covid19 cases per million by month', pad=15)

fig.tight_layout()

mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el1540028771254071286691571879"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
# ...
